# %% [markdown]
# 📌 Só se tiver análise exploratória de negócio
#
# Use para:
#
# responder perguntas específicas
#
# simular cenários
#
# gerar gráficos finais
#
# Se tudo for direto pro BI, pode nem existir.
