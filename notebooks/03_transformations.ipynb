# %% [markdown]
# 📌 Onde seu trabalho atual entra muito bem
#
# Use para:
#
# tratar nulos com regra clara
#
# criar colunas novas (flags, buckets, categorias)
#
# padronizar formatos
#
# testar joins
#
# ⚠️ Importante:
#
# se a transformação “fixou”, vira código no src/ ou SQL
#
# notebook é só laboratório
