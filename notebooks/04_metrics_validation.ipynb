# %% [markdown]
# 📌 Esse separa júnior de pleno/sênior
#
# Use para:
#
# validar KPIs
#
# bater número com fonte original
#
# responder: “esse número faz sentido?”
#
# Exemplo:
#
# total de receita ≠ financeiro → por quê?
#
# usuários ativos → definição clara
#
# 👉 Esse notebook evita desastre em dashboard.
