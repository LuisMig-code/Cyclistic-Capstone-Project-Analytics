# %% [markdown]
# Vale se você:
#
# Calcula métricas no Python
#
# Depois recria em DAX
#
# Notebook tipo:
#
# powerbi_checks.ipynb
#
#
# Serve pra responder:
#
# “Esse KPI bate com o que o BI mostra?”
